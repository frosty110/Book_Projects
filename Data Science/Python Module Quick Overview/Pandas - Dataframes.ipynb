# %% [markdown]
# # Dataframes

# %% [markdown]
# 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'

# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
#Copy and read to get data
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
#
#   Total Games   Division
# 0         882   NFC East
# 1       1,336  NFC North
# 2       1,370  NFC North
# 3         800   AFC East
# 4         884   AFC East

# %%
# We can grab the oclumn names with .columns
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
#Lets see some specific data columns
DataFrame(nfl_frame,columns=['Team','First Season','Total Games'])
# Out:
#                       Team  First Season Total Games
# 0           Dallas Cowboys           NaN         882
# 1        Green Bay Packers           NaN       1,336
# 2            Chicago Bears           NaN       1,370
# 3           Miami Dolphins           NaN         800
# 4  New England Patriots[b]           NaN         884

# %%
#What happens if we ask for a column that doesn't exist?
DataFrame(nfl_frame,columns=['Team','First Season','Total Games','Stadium','aosdnibdwibuabdiauwbd'])
# Out:
#                       Team  First Season Total Games  Stadium  \
# 0           Dallas Cowboys           NaN         882      NaN
# 1        Green Bay Packers           NaN       1,336      NaN
# 2            Chicago Bears           NaN       1,370      NaN
# 3           Miami Dolphins           NaN         800      NaN
# 4  New England Patriots[b]           NaN         884      NaN
#
#    aosdnibdwibuabdiauwbd
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
# Call columns
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
#We can retrieve individual columns
nfl_frame.Team
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# Name: Team, dtype: object

# %%
nfl_frame.Team
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# Name: Team, dtype: object

# %%
#We can retrieve rows through indexing
nfl_frame.ix[3]
# Out:
# C:\Users\Hazz\Anaconda3\envs\untitled2\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# Rank                             4
# Team                Miami Dolphins
# Won                            445
# Lost                           351
# Tied                             4
# Pct.                         0.559
# First NFL Season              1966
# Total Games                    800
# Division                  AFC East
# Name: 3, dtype: object

# %%
#We can also assign value sto entire columns
nfl_frame['Stadium']="Levi's Stadium" #Careful with the ' here
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
#
#   Total Games   Division         Stadium
# 0         882   NFC East  Levi's Stadium
# 1       1,336  NFC North  Levi's Stadium
# 2       1,370  NFC North  Levi's Stadium
# 3         800   AFC East  Levi's Stadium
# 4         884   AFC East  Levi's Stadium

# %%
nfl_frame['aosdnibdwibuabdiauwbd'] = 'what'
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
#
#   Total Games   Division         Stadium aosdnibdwibuabdiauwbd
# 0         882   NFC East  Levi's Stadium                  what
# 1       1,336  NFC North  Levi's Stadium                  what
# 2       1,370  NFC North  Levi's Stadium                  what
# 3         800   AFC East  Levi's Stadium                  what
# 4         884   AFC East  Levi's Stadium                  what

# %%
#Putting numbers for stadiums
nfl_frame["Stadium"] = np.arange(5)
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
#
#   Total Games   Division  Stadium aosdnibdwibuabdiauwbd
# 0         882   NFC East        0                  what
# 1       1,336  NFC North        1                  what
# 2       1,370  NFC North        2                  what
# 3         800   AFC East        3                  what
# 4         884   AFC East        4                  what

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division', 'Stadium', 'aosdnibdwibuabdiauwbd'],
#       dtype='object')

# %%
#Adding a Series to a DataFrame
stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium']=stadiums
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
#
#   Total Games   Division         Stadium aosdnibdwibuabdiauwbd
# 0         882   NFC East    AT&T Stadium                  what
# 1       1,336  NFC North             NaN                  what
# 2       1,370  NFC North             NaN                  what
# 3         800   AFC East             NaN                  what
# 4         884   AFC East  Levi's Stadium                  what

# %%
#We can also delete columns
del nfl_frame['Stadium']
del nfl_frame['aosdnibdwibuabdiauwbd']
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
#
#   Total Games   Division
# 0         882   NFC East
# 1       1,336  NFC North
# 2       1,370  NFC North
# 3         800   AFC East
# 4         884   AFC East

# %%
#DataFrames can be constructed many ways. Another way is from a dictionary of equal length lists
data = {'City':['SF','LA','NYC'],
        'Population':[837000,3880000,8400000]}

city_frame = DataFrame(data)

#Show
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
#Now let's see sleection in a DataFrame
dframe = DataFrame(np.arange(25).reshape((5,5)),index=['NYC','LA','SF','DC','Chi'],columns=['A','B','C','D','E'])
#Show
dframe
# Out:
#       A   B   C   D   E
# NYC   0   1   2   3   4
# LA    5   6   7   8   9
# SF   10  11  12  13  14
# DC   15  16  17  18  19
# Chi  20  21  22  23  24

# %%
dframe.B
# Out:
# NYC     1
# LA      6
# SF     11
# DC     16
# Chi    21
# Name: B, dtype: int32

# %%
#Select by multiple columns
dframe[['B','E']]
# Out:
#       B   E
# NYC   1   4
# LA    6   9
# SF   11  14
# DC   16  19
# Chi  21  24

# %%
#Can also use boolean
dframe[dframe['B']>8]
# Out:
#       A   B   C   D   E
# SF   10  11  12  13  14
# DC   15  16  17  18  19
# Chi  20  21  22  23  24

# %%
#Can also just shoe a boolean DataFrame
dframe> 10
# Out:
#          A      B      C      D      E
# NYC  False  False  False  False  False
# LA   False  False  False  False  False
# SF   False   True   True   True   True
# DC    True   True   True   True   True
# Chi   True   True   True   True   True

# %%
#Can alos use ix as previously discussed to label-index
dframe.ix['LA'] # deprecation warning:  http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# Out:
# A    5
# B    6
# C    7
# D    8
# E    9
# Name: LA, dtype: int32

# %% [markdown]
# # Dataframe Math
